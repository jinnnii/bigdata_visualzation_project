# %%
import urllib.request as req
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

import pymysql

# %%
url='https://movie.naver.com/movie/running/current.naver'
res = requests.get(url)
res.encoding='utf-8'

bs = BeautifulSoup(res.text, 'html.parser')
movie_list = bs.select('div.lst_wrap > ul > li')

base='https://movie.naver.com'

pd_list =[]

for movie in movie_list:
    img_url = movie.select_one('.thumb>a>img')['src']
    rating = movie.select_one('.tit>span').string
    title = movie.select_one('.tit>a').string
    detail_url=movie.select_one('.tit>a')['href']
    genres,time,date= movie.select_one('dl > dd:nth-child(3) > dl > dd').text.replace('\t','').replace('\n','').replace('\r','').replace('분','').replace(' 개봉','').split('|')
    genres = genres.split(', ')
    director = movie.select_one('dl > dd:nth-child(3) > dl > dd:nth-child(4)>span>a').string
    actors= movie.select_one('dl > dd:nth-child(3) > dl > dd:nth-child(6)>span')
    actors = actors.text.replace('\t','').replace('\n','').replace('\r','').split(', ') if actors else []
    user_star, *writer_star = [num.text for num in movie.select('.star .num')]
    writer_star=''.join(writer_star)
    
    
    
    
    pd_list.append((title,rating,genres,time,date, director, actors,user_star,writer_star))
    
df = pd.DataFrame(pd_list,columns=['title','rating','genres','time','date','director','actors','user_star','writer_star'])
df
# Out:
# /movie/bi/mi/basic.naver?code=150389
# /movie/bi/mi/basic.naver?code=194096
# /movie/bi/mi/basic.naver?code=191646
# /movie/bi/mi/basic.naver?code=50368
# /movie/bi/mi/basic.naver?code=208772
# /movie/bi/mi/basic.naver?code=206637
# /movie/bi/mi/basic.naver?code=217276
# /movie/bi/mi/basic.naver?code=173288
# /movie/bi/mi/basic.naver?code=210768
# /movie/bi/mi/basic.naver?code=87717
# /movie/bi/mi/basic.naver?code=213495
# /movie/bi/mi/basic.naver?code=213541
# /movie/bi/mi/basic.naver?code=216100
# /movie/bi/mi/basic.naver?code=215579
# /movie/bi/mi/basic.naver?code=206622
# /movie/bi/mi/basic.naver?code=203461
# /movie/bi/mi/basic.naver?code=204882
# /movie/bi/mi/basic.naver?code=199908
# /movie/bi/mi/basic.naver?code=195439
# /movie/bi/mi/basic.naver?code=192608
# /movie/bi/mi/basic.naver?code=207202
# /movie/bi/mi/basic.naver?code=201336
# /movie/bi/mi/basic.naver?code=213601
# /movie/bi/mi/basic.naver?code=200060
# /movie/bi/mi/basic.naver?code=169086
# /movie/bi/mi/basic.naver?code=206647
# /movie/bi/mi/basic.naver?code=191912
# /movie/bi/mi/basic.naver?code=197945
# /movie/bi/mi/basic.naver?code=208824
# /movie/bi/mi/basic.naver?code=214637
# /movie/bi/mi/basic.naver?code=172192
# /movie/bi/mi/basic.naver?code=182016
# /movie/bi/mi/basic.naver?code=202675
# /movie/bi/mi/basic.naver?code=196047
# /movie/bi/mi/basic.naver?code=194842
# /movie/bi/mi/basic.naver?code=206217
# /movie/bi/mi/basic.naver?code=159812
# /movie/bi/mi/basic.naver?code=215791
# /movie/bi/mi/basic.naver?code=200450
# /movie/bi/mi/basic.naver?code=212159
# /movie/bi/mi/basic.naver?code=198501
# /movie/bi/mi/basic.naver?code=197065
# /movie/bi/mi/basic.naver?code=194908
# /movie/bi/mi/basic.naver?code=17059
# /movie/bi/mi/basic.naver?code=204138
# /movie/bi/mi/basic.naver?code=201938
# /movie/bi/mi/basic.naver?code=198624
# /movie/bi/mi/basic.naver?code=201766
# /movie/bi/mi/basic.naver?code=164122
# /movie/bi/mi/basic.naver?code=193961
# /movie/bi/mi/basic.naver?code=213576
# /movie/bi/mi/basic.naver?code=29446
# /movie/bi/mi/basic.naver?code=194668
# /movie/bi/mi/basic.naver?code=213733
# /movie/bi/mi/basic.naver?code=194813
# /movie/bi/mi/basic.naver?code=187320
# /movie/bi/mi/basic.naver?code=205623
# /movie/bi/mi/basic.naver?code=207940
# /movie/bi/mi/basic.naver?code=205129
# /movie/bi/mi/basic.naver?code=201073
# /movie/bi/mi/basic.naver?code=192150
# /movie/bi/mi/basic.naver?code=19335
# /movie/bi/mi/basic.naver?code=134963
# /movie/bi/mi/basic.naver?code=28876
# /movie/bi/mi/basic.naver?code=189634
# /movie/bi/mi/basic.naver?code=189079
# /movie/bi/mi/basic.naver?code=191469
# /movie/bi/mi/basic.naver?code=175045
# /movie/bi/mi/basic.naver?code=16411
# /movie/bi/mi/basic.naver?code=172145
# /movie/bi/mi/basic.naver?code=172344
# /movie/bi/mi/basic.naver?code=10546
# /movie/bi/mi/basic.naver?code=50749
# /movie/bi/mi/basic.naver?code=123389
# /movie/bi/mi/basic.naver?code=109920
# /movie/bi/mi/basic.naver?code=49085
# /movie/bi/mi/basic.naver?code=90537
# /movie/bi/mi/basic.naver?code=74516
# /movie/bi/mi/basic.naver?code=40027
# /movie/bi/mi/basic.naver?code=19379
# /movie/bi/mi/basic.naver?code=20664
# /movie/bi/mi/basic.naver?code=10070
# /movie/bi/mi/basic.naver?code=10478
# /movie/bi/mi/basic.naver?code=11995
#                              title   rating              genres time  \
# 0                  올리 마키의 가장 행복한 날  12세 관람가       [멜로/로맨스, 드라마]   93
# 1                      괴물, 유령, 자유인  15세 관람가        [SF, 멜로/로맨스]   77
# 2                     쥬라기 월드: 도미니언  12세 관람가            [액션, 모험]  147
# 3   극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미   전체 관람가             [애니메이션]   96
# 4                            카시오페아  12세 관람가               [드라마]  102
# ..                             ...      ...                 ...  ...
# 79                          여름 이야기  12세 관람가       [코미디, 멜로/로맨스]  114
# 80                          로맨스 빠빠  15세 관람가        [가족, 멜로/로맨스]  131
# 81                       OK 목장의 결투  12세 관람가       [서부, 액션, 스릴러]  117
# 82                         젊은이의 양지  15세 관람가  [드라마, 느와르, 멜로/로맨스]  122
# 83                            가스등   15세 관람가          [스릴러, 드라마]  114
#
#           date  director                                 actors user_star  \
# 0   2022.06.02  유호 쿠오스마넨              [에로 밀로노프, 자코 라티, 우나 아이롤라]      0.00
# 1   2022.06.02       홍지영                        [엄태나, 윤해신, 권기하]      0.00
# 2   2022.06.01  콜린 트레보로우                 [크리스 프랫, 브라이스 달라스 하워드]      6.36
# 3   2022.06.01  유야마 쿠니히코  [이선호, 김영선, 마츠모토 리카, 오오타니 이쿠에, 우에다 유지]      7.45
# 4   2022.06.01       신연식                        [안성기, 서현진, 주예림]      9.37
# ..         ...       ...                                    ...       ...
# 79  1998.06.13    에릭 로메르                       [멜빌 푸포, 아만다 랑글렛]      8.12
# 80  1960.01.28       신상옥             [최은희, 김진규, 강신성일, 김승호, 주증녀]      8.52
# 81  1958.01.01    존 스터지스                     [버트 랭커스터, 커크 더글러스]      8.68
# 82  1953.11.26   조지 스티븐스         [몽고메리 클리프트, 엘리자베스 테일러, 쉘리 윈터스]      8.81
# 83  1948.04.21     조지 큐커            [샤를르 보와이에, 잉그리드 버그만, 조셉 거튼]      8.56
#
#    writer_star
# 0         8.00
# 1
# 2
# 3         6.00
# 4         6.50
# ..         ...
# 79        6.00
# 80
# 81
# 82
# 83
#
# [84 rows x 9 columns]

# %%
def get_detail(url):
    res = requests.get(url)
    res.encoding='utf-8'
    bs=BeautifulSoup(res.text,'html.parser')
    
    bstory = bs.select_one('.h_tx_story').text
    mstory = ''.join( txt.replace('\r','').replace('\xa0','') for txt in bs.select_one('.con_tx').find_all(text=True))
    
    graph = bs.select_one('div.mv_info div.bar_graph')
    
    temp=[]
    
    if graph:
        pers = graph.select('.graph_percent')
        ages = graph.select('.graph_legend>span')
        
       
        for per,age in zip(pers,ages):
            temp.append(per.text+age.text)
    else:
        temp.append('정보 없음')
    
    return (temp,mstory)
    
    
detail_url='https://movie.naver.com/movie/bi/mi/basic.naver?code=191646'
temp, story = get_detail(detail_url)
print(temp,story)
# Out:
# ['3%10', '30%20', '44%30', '17%40', '6%50'] 공룡들의 터전이었던 이슬라 누블라 섬이 파괴된 후,마침내 공룡들은 섬을 벗어나 세상 밖으로 출몰한다. 지상에 함께 존재해선 안 될 위협적 생명체인 공룡의 등장으로인류 역사상 겪어보지 못한 사상 최악의 위기를 맞이한 인간들.지구의 최상위 포식자 자리를 걸고 인간과 공룡의 최후의 사투가 펼쳐진다.

# %%
detail_url='https://movie.naver.com/movie/bi/mi/basic.naver?code=191646'
get_detail(detail_url)
# Out:
# 이제 모든 것이 끝난다,
# 지상 최대 블록버스터의 압도적 피날레!
# 공룡들의 터전이었던 이슬라 누블라 섬이 파괴된 후,마침내 공룡들은 섬을 벗어나 세상 밖으로 출몰한다. 지상에 함께 존재해선 안 될 위협적 생명체인 공룡의 등장으로인류 역사상 겪어보지 못한 사상 최악의 위기를 맞이한 인간들.지구의 최상위 포식자 자리를 걸고 인간과 공룡의 최후의 사투가 펼쳐진다.
