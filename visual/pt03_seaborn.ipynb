# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
# %matplotlib inline

# %%
# 그림 크기 설정
plt.rcParams['figure.figsize']=(12,9)

# %%
# 타이타닉 데이터 로드
titanic= sns.load_dataset('titanic')
print(titanic.shape)
titanic.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.get_dataset_names() #seaborn 데이터 셋 모음
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
print(tips.shape)
tips.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='class',hue='who', data=titanic)
plt.show()

# %%
sns.countplot(x='class', data=titanic)
plt.show()

# %%
sns.countplot(x='class', hue='who', palette='Accent', data=titanic)
# pallette 값 입력 오류 시, 사용가능한 palette명 표시
# ex_ palette = 'Accent11111'

plt.show()

# %%
# seaborn color palette 사용
# 참조 사이트 : https://www.

current_palette = sns.color_palette()
sns.palplot(current_palette)
plt.show()

sns.palplot(sns.color_palette('Greys'))
sns.palplot(sns.color_palette('terrain_r',7))
sns.palplot(sns.color_palette('deep',10))
sns.palplot(sns.color_palette('muted',10))
# sns.palplot(sns.color_palette('bright',10))
# sns.palplot(sns.color_palette('dark',10))

# color=['green','white','red','yellow','green','gray']
# sns.set_palette(color)
# sns.palplot(sns.color_palette())

sns.set_palette(sns.color_palette('muted',10))

# %%
#sns.relplot(x='x축으로 사용할 필드', y='y축으로 사용할 필드', data='dataFrame')
# sns.relplot(x='total_bill', y='tip', data=tips)
sns.scatterplot(x='total_bill', y='tip', data=tips)

print(tips.total_bill.corr(tips.tip))
# Out:
# 0.6757341092113646

# %%
sns.relplot(x='total_bill', y='tip', data=tips,hue='smoker', palette=['red','blue'])

# %%
sns.relplot(x='total_bill',y='tip',hue='day', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='size')
            #수치형 데이터로 지정했을 때, 연속성을 갖는 색상으로 제공

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker', hue='size')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, size='size', hue='size')

# %%
#row와 column에 표기할 데이터 분리
sns.relplot(x='total_bill', y='tip', hue='day', row='sex', data=tips)
sns.relplot(x='total_bill', y='tip', hue='day', col='smoker', data=tips)

# %%
#row와 column에 표기할 데이터 분리
sns.relplot(x='total_bill', y='tip', hue='smoker'
            , col='day', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='day',
            row='sex',col='time', data=tips)

# %%
#relplot으로 line그래프 그리기
# arrange(0,500,1) : 0부터 499까지 증가 
# random.randn(500) : -1 부터 1까지 랜덤 숫자 500개 생성
#cumsum() : 누적합
df=pd.DataFrame(dict(time=np.arange(0,500,1), value=np.random.randn(500).cumsum()))
df
# Out:
#      time     value
# 0       0 -0.934129
# 1       1 -0.430511
# 2       2  0.180445
# 3       3 -0.881778
# 4       4 -1.565031
# ..    ...       ...
# 495   495  5.482237
# 496   496  5.586952
# 497   497  5.140080
# 498   498  6.292287
# 499   499  5.442668
#
# [500 rows x 2 columns]

# %%
plt.rcParams['axes.unicode_minus']=False
sns.relplot(x='time',y='value', data=df, kind='line')

# %%
fmri= sns.load_dataset('fmri')
print(fmri.shape)
fmri
# Out:
# (1064, 5)
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
#95% 신뢰구간 보여줌
# line : 좌표의 평균 값
# arange : 95%에 포함되어있는 구간
sns.relplot(x='timepoint', y='signal',data=fmri, kind='line')

# %%
sns.relplot(x='timepoint',y='signal', data=fmri, kind='line', ci=None)

# %%
sns.relplot(x='timepoint',y='signal', data=fmri, kind='line', ci=50)

# %%
sns.relplot(x='timepoint',y='signal', data=fmri, kind='line', ci='sd')

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line',
            hue='region', style='event')

# %%
x=np.random.randn(100)
x
# Out:
# array([ 1.18953754, -0.59186536,  1.71822506,  0.43413054,  0.87260678,
#         1.2852593 ,  2.3634636 , -0.70011542, -0.28228116, -0.38018647,
#        -0.38418587, -1.63633405, -1.75657323,  0.20796532, -0.95949681,
#        -1.86057827,  0.07262567, -0.88705479, -2.09058369, -0.27079288,
#        -0.66694911, -1.41554431, -0.37683409, -0.3290729 ,  0.49520018,
#        -0.69965514, -0.54726329,  0.62269488, -0.01025648, -0.49053465,
#         0.37151615,  0.05201283,  0.9813029 , -0.18090416,  0.66318271,
#         0.00718629,  0.79613298, -0.24436693,  0.66261381, -0.95788245,
#        -0.18553305,  0.17226464, -0.90693509,  0.00962486, -0.01453322,
#        -0.55075102, -1.5408314 ,  0.25316501,  0.56023439,  0.75477905,
#        -0.64568874,  0.67370525, -2.61567453, -0.73058829,  0.20881661,
#         0.00576503, -1.05315163, -2.02169289, -0.20138081,  1.90393053,
#         1.01970843,  0.65293974, -2.48041759, -0.52217644, -0.45046508,
#        -0.50674672,  0.82840386,  0.85741553,  0.37640203, -1.501393  ,
#        -2.39447895,  0.44626896, -0.40198437,  0.34007075, -1.01652636,
#         0.31007792, -1.03715694, -0.57130785,  1.58432878,  1.99079937,
#        -0.76343625,  2.10872161,  0.210448  ,  0.69400622,  0.78926729,
#         0.9347565 ,  0.40490337, -1.18107059, -0.69289587,  1.12722532,
#        -1.98090234, -0.69403678,  0.44467347, -0.39127385, -1.34784017,
#        -0.32692111, -1.79267757,  1.59371604,  1.39904233, -1.2350837 ])

# %%
sns.distplot(x)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x,rug=True, hist=False, kde=True)
# plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(x)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.hist(x)
# Out:
# (array([ 3.,  7.,  6., 15., 21., 15., 18.,  7.,  4.,  4.]),
#  array([-2.61567453, -2.11776072, -1.61984691, -1.12193309, -0.62401928,
#         -0.12610546,  0.37180835,  0.86972216,  1.36763598,  1.86554979,
#          2.3634636 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(x,rug=True,hist=False, kde=False)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
#kde는 histogram 보다 부드러운 형태의 분포 곡선을 보여주는 방법
sns.distplot(x,rug=False, hist=False, kde=True)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x,vertical=True)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density'>

# %%
#컬러 변경하기 : r,g,b,c,m,y 가능
sns.distplot(x,color='r')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#histplot() 사용
# sns.histplot(data=x, kde=True)
sns.rugplot(x=x)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=tips.total_bill, kde=True)
sns.rugplot(x=tips.total_bill)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
heatmap_data = np.random.rand(10,12)
sns.heatmap(heatmap_data, annot=False) #annot=True로 해야 수치 표현 가능
# Out:
# <AxesSubplot:>

# %%
pivot = tips.pivot_table(index='day', columns='size',values='tip')
pivot
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000       NaN  NaN
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  NaN
# Sun    NaN  2.816923  3.120667  4.087778  4.046667  5.0

# %%
sns.heatmap(pivot,cmap='Reds', annot=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='day'>

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(), annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>
