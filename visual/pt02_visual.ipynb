# %%
from matplotlib import rc, font_manager
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
rc('font',family=font_name)
df = pd.DataFrame(np.random.rand(6,4),
                  index=['one','two','three','four','five','six'],
                  columns=pd.Index(['A','B','C','D'],name='-종류-'))
df
# Out:
# -종류-          A         B         C         D
# one    0.282356  0.141418  0.489042  0.349370
# two    0.310262  0.862470  0.090525  0.840461
# three  0.544179  0.172607  0.757253  0.316091
# four   0.547085  0.370247  0.819313  0.596102
# five   0.456395  0.795477  0.466591  0.450622
# six    0.857346  0.146604  0.987106  0.255348

# %%
plt.rcParams['axes.unicode_minus']=False
df.plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:>

# %%
s3=pd.Series(np.random.normal(0,100,size=200))
s3.head()
# s3
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['axes.unicode_minus']=False
s3.hist()
s3.hist(bins=50)
# s3.hist(bins=100, normed=True)
s3.hist(cumulative=True)
# Out:
# <AxesSubplot:>

# %%
import csv
from datetime import datetime

filename='data/temperature_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates,highs,lows=[],[],[]
    for row in reader:
        try:
            #strftime : 날짜를 문자열로
            #strptiem : 문자열을 날짜로
            current_date = datetime.strptime(row[0],'%Y-%m-%d')
            high=int(row[1])
            low=int(row[3])
        except ValueError:
            print(current_date,'missing date')
        else: #예외가 발생하지 않으면 리스트 추가
            dates.append(current_date)
            highs.append(high)
            lows.append(low)
flg = plt.figure(dpi=128, figsize=(10,6))
# x축 dates, y축 highs, 색상 red
# 투명도 0.5 범위 :0.0~1.0
plt.plot(dates,highs, c='red', alpha=0.5)
plt.plot(dates,lows, c='blue', alpha=0.5)

#두개의 선 사이(highs~lows)를 색칠함, alpha=0.1 투명도 0.1
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)
#그래프 스타일
plt.title('온도 통계', fontsize=20)
plt.xlabel('기간',fontsize=16)
plt.ylabel('온도',fontsize=16)
plt.tick_params(axis='both', labelsize=16) #눈금 표시
plt.savefig('chart.png',dpi=400, bbox_inches='tight')
plt.show()
# Out:
# 2014-02-16 00:00:00 missing date

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot([1,2,3,4],[1,2,3,4])
plt.subplot(2,1,2)
plt.plot([5,6,7,8],[5,6,7,8])
plt.show()

# %%
plt.plot([1,2,3,4],[1,2,3,4])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('matplotlib활용') #그래프 제목
plt.text(3.5,3.0,'평균:2.5') #그래프 지정 위치에 문자열 표시
plt.grid(True) #인덱스마다 격자를 나타냄
plt.show()
