# %%
import pandas as pd
cb = pd.read_csv('data/coffeebean.csv', encoding='CP949', index_col=0, header=0)
cb.head()
# Out:
#      store                     address         phone
# 0  학동역 DT점        서울시 강남구 학동로 211 1층    02-3444-9973
# 1      수서점  서울시 강남구 광평로 280 수서동 724호    02-3412-2326
# 2     차병원점   서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 3    강남대로점       서울시 서초구 강남대로 369 1층     02-588-5778
# 4    메가박스점  서울 강남구 삼성동 159 코엑스몰 지하2층    02-6002-3320

# %%
addr=[]
for a in cb.address:
    addr.append(a.split())
addr
# Out:
# [['서울시', '강남구', '학동로', '211', '1층'],
#  ['서울시', '강남구', '광평로', '280', '수서동', '724호'],
#  ['서울시', '강남구', '논현로', '566', '강남차병원1층'],
#  ['서울시', '서초구', '강남대로', '369', '1층'],
#  ['서울', '강남구', '삼성동', '159', '코엑스몰', '지하2층'],
#  ['서울시', '강남구', '압구정로', '46길', '3'],
#  ['서울시', '서초구', '서초', '1306-3호'],
#  ['서울시', '강남구', '압구정로', '461', '네이처포엠빌딩B108,109호'],
#  ['서울시', '강남구', '도산대로', '126'],
#  ['서울시', '강남구', '논현로', '842', '압구정빌딩1층'],
#  ['서울시', '강남구', '논현로', '512', '지상1,2층'],
#  ['서울시', '서초구', '강남대로', '213', '24호', '지하1층'],
#  ['서울시', '강남구', '삼성로', '716', 'LEE76빌딩2층'],
#  ['서울', '서초구', '반포동', '736-17', 'P빌딩', '2층'],
#  ['서울시', '강남구', '언주로', '30길', '10,112', '현대비젼21', '112호'],
#  ['서울시', '강남구', '선릉로', '749', '1,2층'],
#  ['서울시', '강남구', '테헤란로', '87길', '17', '1층'],
#  ['서울시', '서초구', '서초중앙로', '118', '1층'],
#  ['서울시', '강남구', '선릉로', '64길', '23', '1층'],
#  ['서울시', '강남구', '도산대로49길', '13', '1층', '17,18호'],
#  ['서울시', '강남구', '선릉로', '157길', '12', '석전빌딩', '1~4층'],
# ...

# %%
#행정 구역 표준 이름이 아닌 거 수정하기

addr_list=[]
for i,v in enumerate(addr):
    v=v[0]
    
    if v=='서울':addr[i][0]='서울특별시'
    elif v=='서울시' : addr[i][0]='서울특별시'
    elif v=='부산시' : addr[i][0]='부산광역시'
    elif v=='인천' : addr[i][0]='인천광역시'
    elif v=='광주' : addr[i][0]='광주광역시'
    elif v=='대전시' : addr[i][0]='대전광역시'
    elif v=='울산시' : addr[i][0]='울산광역시'
    elif v=='세종시' : addr[i][0]='세종특별자치시'
    elif v=='경기' : addr[i][0]='경기도'
    elif v=='충북' : addr[i][0]='충청북도'
    elif v=='충남' : addr[i][0]='충청남도'
    elif v=='전북' : addr[i][0]='전라북도'
    elif v=='전남' : addr[i][0]='전라남도'
    elif v=='경북' : addr[i][0]='경상북도'
    elif v=='경남' : addr[i][0]='경상남도'
    elif v=='제주' : addr[i][0]='제주특별자치도'
    elif v=='제주도' : addr[i][0]='제주특별자치도'
    elif v=='제주시' : addr[i][0]='제주특별자치도'
    
    addr_list.append(' '.join(addr[i]))
addr_list
# Out:
# ['서울특별시 강남구 학동로 211 1층',
#  '서울특별시 강남구 광평로 280 수서동 724호',
#  '서울특별시 강남구 논현로 566 강남차병원1층',
#  '서울특별시 서초구 강남대로 369 1층',
#  '서울특별시 강남구 삼성동 159 코엑스몰 지하2층',
#  '서울특별시 강남구 압구정로 46길 3',
#  '서울특별시 서초구 서초 1306-3호',
#  '서울특별시 강남구 압구정로 461 네이처포엠빌딩B108,109호',
#  '서울특별시 강남구 도산대로 126',
#  '서울특별시 강남구 논현로 842 압구정빌딩1층',
#  '서울특별시 강남구 논현로 512 지상1,2층',
#  '서울특별시 서초구 강남대로 213 24호 지하1층',
#  '서울특별시 강남구 삼성로 716 LEE76빌딩2층',
#  '서울특별시 서초구 반포동 736-17 P빌딩 2층',
#  '서울특별시 강남구 언주로 30길 10,112 현대비젼21 112호',
#  '서울특별시 강남구 선릉로 749 1,2층',
#  '서울특별시 강남구 테헤란로 87길 17 1층',
#  '서울특별시 서초구 서초중앙로 118 1층',
#  '서울특별시 강남구 선릉로 64길 23 1층',
#  '서울특별시 강남구 도산대로49길 13 1층 17,18호',
#  '서울특별시 강남구 선릉로 157길 12 석전빌딩 1~4층',
#  '서울특별시 서초구 강남대로 51길 1 511 TOWER 1층',
#  '서울특별시 강남구 논현 231-13호 팍스타워지하1층',
#  '서울특별시 강남구 영동대로 513 컨벤션별관A동 지하 2층',
#  '서울특별시 강남구 영동대로 511 트레이드타워 지하1층',
#  '서울특별시 강남구 영동대로 607 12번지 1,2층',
#  '서울특별시 강남구 삼성로 85길 11 롯데캐슬아파트생활편익시설동',
#  '서울특별시 서초구 신반포로 23 1141호 엘루체백화점내1층1013~1015호',
#  '서울특별시 송파구 석촌호수로 118 1층',
# ...

# %%
addr_df = pd.DataFrame(addr_list, columns=['address2'])
addr_df
# Out:
#                                        address2
# 0                          서울특별시 강남구 학동로 211 1층
# 1                    서울특별시 강남구 광평로 280 수서동 724호
# 2                     서울특별시 강남구 논현로 566 강남차병원1층
# 3                         서울특별시 서초구 강남대로 369 1층
# 4                   서울특별시 강남구 삼성동 159 코엑스몰 지하2층
# ..                                          ...
# 238  인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)
# 239                       부산광역시 부산진구 서전로 12, 1층
# 240                   경기도 성남시 분당구 야탑로64 DS타워 1층
# 241                            서울특별시 용산구 한강대로95
# 242                   서울특별시 강남구 선릉로 433 세방빌딩 1층
#
# [243 rows x 1 columns]

# %%
# cb2 = pd.concat([cb,addr_df],axis=1)
cb['address2']=addr_list
cb.head()
# Out:
#      store                     address         phone  \
# 0  학동역 DT점        서울시 강남구 학동로 211 1층    02-3444-9973
# 1      수서점  서울시 강남구 광평로 280 수서동 724호    02-3412-2326
# 2     차병원점   서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 3    강남대로점       서울시 서초구 강남대로 369 1층     02-588-5778
# 4    메가박스점  서울 강남구 삼성동 159 코엑스몰 지하2층    02-6002-3320
#
#                       address2
# 0         서울특별시 강남구 학동로 211 1층
# 1   서울특별시 강남구 광평로 280 수서동 724호
# 2    서울특별시 강남구 논현로 566 강남차병원1층
# 3        서울특별시 서초구 강남대로 369 1층
# 4  서울특별시 강남구 삼성동 159 코엑스몰 지하2층

# %%
cb.to_csv('data/CoffeeBean_2.csv', encoding='CP949', index=False)

# %%
cb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 242
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   store     243 non-null    object
#  1   address   243 non-null    object
#  2   phone     243 non-null    object
#  3   address2  243 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
cb_1= cb[:100]
cb_2= cb[100:200]
cb_3= cb[200:]

cb_1.to_csv('data/cb_1.csv',encoding='CP949', index=False)
cb_2.to_csv('data/cb_2.csv',encoding='CP949', index=False)
cb_3.to_csv('data/cb_3.csv',encoding='CP949', index=False)

# %%
cb_df1=pd.read_csv('data/cb_geo1.shp.csv', encoding='cp949')
cb_df1 = cb_df1.iloc[:,1:] #store X
cb_df1
# Out:
#                             address         phone  \
# 0              서울시 강남구 학동로 211 1층    02-3444-9973
# 1        서울시 강남구 광평로 280 수서동 724호    02-3412-2326
# 2         서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 3             서울시 서초구 강남대로 369 1층     02-588-5778
# 4        서울 강남구 삼성동 159 코엑스몰 지하2층    02-6002-3320
# ..                              ...           ...
# 95  서울시 강북구 도봉로 352 효성네오인텔리안 101호     02-906-5571
# 96    서울시 강남구 논현로 167길 9 낙산프라자 1층     02-545-3181
# 97       서울시 구로구 경인로 662 디큐브시티 4층    02-2210-9484
# 98                서울시 종로구 삼청로 109     02-730-5177
# 99        서울시 중구 퇴계로 173 남산스퀘어 1층    02-2273-3181
#
#                            address2
# 0              서울특별시 강남구 학동로 211 1층
# 1        서울특별시 강남구 광평로 280 수서동 724호
# 2         서울특별시 강남구 논현로 566 강남차병원1층
# 3             서울특별시 서초구 강남대로 369 1층
# 4       서울특별시 강남구 삼성동 159 코엑스몰 지하2층
# ..                              ...
# 95  서울특별시 강북구 도봉로 352 효성네오인텔리안 101호
# 96    서울특별시 강남구 논현로 167길 9 낙산프라자 1층
# ...

# %%
cb_df2=pd.read_csv('data/cb_geo2.shp.csv', encoding='cp949')
cb_df2 = cb_df2.iloc[:,1:] #store X
cb_df2
# Out:
#                                               address         phone  \
# 0                              서울시 영등포구 국제금융로 20 1층     02-783-3391
# 1                                  서울시 강남구 테헤란로 439    02-508-7522
# 2                          서울시 강남구 선릉로93길 6(역삼동) 1층     02-552-3177
# 3                     서울시 강남구 테헤란로1길 29 1층일부 및 2.3층     02-552-6311
# 4                             서울시 강남구 삼성로 551 1층,2층    02-552-9311
# ..                                                ...           ...
# 95                         경기도 부천시 길주로 111 센타플라자 1층    032-329-9471
# 96                  경기도 안양시 만안구 안양로304번길 12 세진빌딩 2층    031-468-9096
# 97                         강원도 원주시 봉화로1 AK플라자원주점 1층    033-748-0631
# 98  서울특별시 송파구 송파대로 111, 송파 파크하비오 하비오길 극장로 203동 지하1층     02-449-6797
# 99        경기도 고양시 덕양구 화신로260번길 26 동민프라자 1층 103~107호    031-979-9402
#
#                                            address2
# 0                            서울특별시 영등포구 국제금융로 20 1층
# ...

# %%
cb_df3=pd.read_csv('data/cb_geo3.shp.csv', encoding='cp949')
cb_df3 = cb_df3.iloc[:,1:] #store X
cb_df3
# Out:
#                                              address          phone  \
# 0                            서울특별시 강남구 테헤란로 111 2층      02-569-5838
# 1                     서울특별시 서초구 서초대로 397 부띠크모나코 1층      02-537-4662
# 2       서울특별시 송파구 송파대로 111 송파파크하비오 205동 1층 110-113      02-449-6881
# 3                 서울 송파구 문정동 643-1번지 엠스테이트 B동 지하1층     02-6177-9080
# 4                             서울특별시 중랑구 망우로 291 1층      02-493-8902
# 5                        서울특별시 강동구 동남로 885 양지빌딩 1층      02-481-9938
# 6                          서울시 노원구 노해로 490, 길빌딩 2층      02-952-9577
# 7                               서울시 마포구 독막로 13, 2층      02-338-9178
# 8                                 서울시 종로구 종로 70 2층      02-739-6268
# 9                        경기도 평택시 평남로 862, 로이드빌딩 1층     031-692-2405
# 10                       서울시 송파구 방이동 44-2, 장은빌딩 1층     02-2141-0407
# 11                   서울특별시 강남구 도곡동 543-1, 지오빌딩 B1층     02-2058-3027
# 12  서울특별시 강북구 한천로 139길 25, 1층 일부 및 2층 (수유동 191-70)      02-994-8878
# ...

# %%
cb_df=pd.concat([cb_df1,cb_df2])
cb_df=pd.concat([cb_df,cb_df3])
cb_df.head()
# Out:
#                                          address          phone  \
# 0                           서울시 강남구 학동로 211 1층     02-3444-9973
# 1                     서울시 강남구 광평로 280 수서동 724호     02-3412-2326
# 2                      서울시 강남구 논현로 566 강남차병원1층      02-538-7615
# 3                          서울시 서초구 강남대로 369 1층      02-588-5778
# 4                     서울 강남구 삼성동 159 코엑스몰 지하2층     02-6002-3320
# ..                                           ...            ...
# 38  인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)     032-743-2894
# 39                       부산광역시 부산진구 서전로 12, 1층     051-819-8708
# 40                   경기도 성남시 분당구 야탑로64 DS타워 1층    031-8017-8243
# 41                              서울시 용산구 한강대로95     02-2074-1049
# 42                   서울특별시 강남구 선릉로 433 세방빌딩 1층     02-2051-9328
#
#                                       address2
# 0                         서울특별시 강남구 학동로 211 1층
# 1                   서울특별시 강남구 광평로 280 수서동 724호
# 2                    서울특별시 강남구 논현로 566 강남차병원1층
# ...

# %%
cb_df = pd.read_csv('data/cb_geo.shp.csv',encoding='cp949')
cb_df = cb_df.iloc[:,1:]
cb_df.head()
# Out:
#       No             store                                       address  \
# 0      1           학동역 DT점                          서울시 강남구 학동로 211 1층
# 1      2               수서점                    서울시 강남구 광평로 280 수서동 724호
# 2      3              차병원점                     서울시 강남구 논현로 566 강남차병원1층
# 3      4             강남대로점                         서울시 서초구 강남대로 369 1층
# 4      5             메가박스점                    서울 강남구 삼성동 159 코엑스몰 지하2층
# ..   ...               ...                                           ...
# 238  239  인천공항 제2여객터미널 입구점  인천광역시 중구 운서동 2868 인천공항 제2터미널 1층 연번(23-124)
# 239  240          부산서면서전로점                       부산광역시 부산진구 서전로 12, 1층
# 240  241         분당차병원본관앞점                   경기도 성남시 분당구 야탑로64 DS타워 1층
# 241  242          신용산역래미안점                              서울시 용산구 한강대로95
# 242  243      선릉역3번출구세방빌딩점                   서울특별시 강남구 선릉로 433 세방빌딩 1층
#
#              phone                                    address2          경도  \
# ...

# %%
cb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   address   243 non-null    object
#  1   phone     243 non-null    object
#  2   address2  243 non-null    object
# dtypes: object(3)
# memory usage: 7.6+ KB

# %%
import folium

# %%
map_osm = folium.Map(location=[37.514678, 127.032052], zoom_start=16)

for i,store in cb_df.iterrows():
    folium.Marker(location=[store['위도'],store['경도']],
                  popup=store['store'],
                  icon=folium.Icon(color='red',icon='star')).add_to(map_osm)
    
map_osm.save('data/map_cb.html')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
cb_df.iterrows()

for data in cb_df.head().iterrows():
    print(data)
# Out:
# (0, store                    학동역 DT점
# address     서울시 강남구 학동로 211 1층
# phone               02-3444-9973
# address2    서울특별시 강남구 학동로 211 1층
# 경도                    127.032052
# 위도                     37.514678
# 상태                           정좌표
# Name: 0, dtype: object)
# (1, store                              수서점
# address     서울시 강남구 광평로 280 수서동 724호
# phone                     02-3412-2326
# address2    서울특별시 강남구 광평로 280 수서동 724호
# 경도                          127.103108
# 위도                           37.487319
# 상태                                 정좌표
# Name: 1, dtype: object)
# (2, store                            차병원점
# address     서울시 강남구 논현로 566 강남차병원1층
# phone                     02-538-7615
# address2    서울특별시 강남구 논현로 566 강남차병원1층
# 경도                         127.034824
# 위도                           37.50644
# 상태                                정좌표
# Name: 2, dtype: object)
# (3, store                       강남대로점
# address     서울시 서초구 강남대로 369 1층
# ...

# %%
import webbrowser

# %%
webbrowser.open('D:/kej/pj/visual/data/map_cb.html')
# Out:
# True
