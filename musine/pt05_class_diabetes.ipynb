# %%
import numpy as np

loaded_data = np.loadtxt('data/diabetes.csv', delimiter=',')

# 학습데이터 분리
seperation_rate=0.3 #분리 비율
test_data_num = int(len(loaded_data)*seperation_rate)

np.random.shuffle(loaded_data)

test_data = loaded_data[0:test_data_num]
training_data = loaded_data[test_data_num:]

#학습할 x 데이터, 학습할 t 데이터
training_x_data = training_data[:,0:-1] #맨 마지막 필드 빼고 전부다
training_t_data = training_data[:,[-1]] #맨 마지막 필드

# 테스트할 x 데이터, 테스트할 t 데이터
test_x_data = test_data[:,0:-1]
test_t_data = test_data[:,[-1]]


print('loaded_data.shape=',loaded_data.shape)
print('training_x_data.shape=',training_x_data.shape)
print('training_t_data.shape=',training_t_data.shape)

print('test_x_data.shape=',test_x_data.shape)
print('test_t_data.shape=',test_t_data.shape)
# Out:
# loaded_data.shape= (759, 9)
# training_x_data.shape= (532, 8)
# training_t_data.shape= (532, 1)
# test_x_data.shape= (227, 8)
# test_t_data.shape= (227, 1)

# %%
W=np.random.rand(8,1)
b= np.random.rand(1)

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def loss_func(x,t):
    delta = 1e-7
    z=np.dot(x,W)+b
    y=sigmoid(z)
    
    #cross-entropy
    return -np.sum(t*np.log(y-delta)+(1-t)*np.log((1-y)+delta))

# %%
# 미분함수 공식
def numerical_derivative(f,x):
    delta_x=1e-4
    grad=np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while not it.finished:
        idx=it.multi_index
        
        tmp_val=x[idx]
        x[idx]=float(tmp_val)+delta_x
        fx1=f(x) #f(x+delta_x)
        
        x[idx]=tmp_val-delta_x
        fx2=f(x) #f(x-detal_x)
        grad[idx]=(fx1-fx2)/(2*delta_x)
        
        x[idx]=tmp_val
        it.iternext()
        
    return grad

# %%
def error_val(x,t):
    delta =1e-7
    
    z=np.dot(x,W)+b
    y=sigmoid(z) 
    #cross-entropy
    return -np.sum(t*np.log(y-delta)+(1-t)*np.log((1-y)+delta))

# %%
#학습을 마친 후 임의의 데이터에 대해 미래 값 예측 함수
# 입력 변수 x:  numpy type

def predict(x):
    z=np.dot(x,W)+b
    y=sigmoid(z)
    
    if y>=0.5:
        result=1 #True
    else:
        result=0 #False
        
    return y,result

# %%
learning_rate = 1e-2

f=lambda x: loss_func(training_x_data,training_t_data) #f(x) = loss_func(x_data,t_data)
print('Initial error value =', error_val(training_x_data,training_t_data),'Initial W=',W, '\nb=',b)

for step in range(20001):
    W-=learning_rate*numerical_derivative(f,W)
    b-=learning_rate*numerical_derivative(f,b)
    
    if(step%1000==0):
        print('step=',step, 'error value=',error_val(training_x_data,training_t_data),'W=',W,'b=',b)
# Out:
# Initial error value = 242.5699028715818 Initial W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]]
# b= [0.60627796]
# step= 0 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 1000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 2000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 3000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 4000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 5000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 6000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 7000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 8000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 9000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 10000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 11000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 12000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 13000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 14000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 15000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 16000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 17000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 18000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 19000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]
# step= 20000 error value= 242.5699028715818 W= [[-1.02492256]
#  [-4.0454218 ]
#  [ 0.41814158]
#  [ 0.0461035 ]
#  [-0.42429879]
#  [-2.70041118]
#  [-0.78581796]
#  [-0.00659473]] b= [0.60627796]

# %%
count=0

for idx, val in enumerate(test_x_data):
    (real_val, logical_val) = predict(val)
    print('real_t_data=',test_t_data[idx], 'real_val=',real_val,'logical_val=',logical_val, test_t_data[idx]==logical_val)
    if test_t_data[idx]==logical_val:
        count+=1

        
print('정확도 : ',count/len(test_x_data))
# Out:
# real_t_data= [1.] real_val= [0.74997203] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.95961503] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.95112689] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.19586875] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.83185734] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.20601483] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.09305113] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.7231487] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.05236285] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.96422423] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.82654952] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.69589295] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.03621003] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.70659471] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.60047284] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.81810976] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.90186345] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.91683607] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.47255308] logical_val= 0 [False]
# real_t_data= [0.] real_val= [0.15695502] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.94414307] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.34207654] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.19165733] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.88867993] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.68535099] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.93467874] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.96234431] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.72993759] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.89170181] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.37087654] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.83645219] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.69806647] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.73696062] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.75427669] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.88624338] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.95829846] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.1207334] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.89837118] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.70630219] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.91641017] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.83061383] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.01697007] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.70702467] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.07235108] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.11087478] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.96194299] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.42307674] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.67603791] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.8460666] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.94364716] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.20768312] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.82779734] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.93223638] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.84922556] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.90793714] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.8703325] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.87687389] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.38387857] logical_val= 0 [False]
# real_t_data= [0.] real_val= [0.74342771] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.20384488] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.10459702] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.11295141] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.89831218] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.90600953] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.97995749] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.93419263] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.96379736] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.96159809] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.95334492] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.83407615] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.58591815] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.45784587] logical_val= 0 [False]
# real_t_data= [0.] real_val= [0.31078582] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.66960878] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.73524758] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.43756719] logical_val= 0 [False]
# real_t_data= [0.] real_val= [0.49176696] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.92814843] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.98195633] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.98028782] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.80576236] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.34742187] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.97859731] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.79695896] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.78969713] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.7643394] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.10259872] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.5561599] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.94940955] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.96948998] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.8565355] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.93440806] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.9606972] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.78136834] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.23878374] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.13399053] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.21646228] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.95519436] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.92595039] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.8533067] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.82657047] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.67255869] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.86898847] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.69623093] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.62525814] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.54912802] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.31928925] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.64103308] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.51327622] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.42839371] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.83953811] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.81786928] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.28209664] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.07994255] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.78732378] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.90952538] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.64956651] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.37364093] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.72790353] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.67567485] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.54148581] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.07445996] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.60202159] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.94414568] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.98365843] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.84979235] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.84312114] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.97252127] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.29591449] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.24373571] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.51710222] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.39864514] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.26066459] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.09307344] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.42439315] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.95028922] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.94147756] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.72764703] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.93391648] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.1447966] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.9410444] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.75981244] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.61442976] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.23171657] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.7029994] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.26384912] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.9017432] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.88587017] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.85530168] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.84421093] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.37371752] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.96833534] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.29935567] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.86085996] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.80823069] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.46674366] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.29693232] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.53350344] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.62580837] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.46489983] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.94845932] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.81824924] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.93474411] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.92824821] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.73000951] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.96898831] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.07966893] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.45371719] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.47260808] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.92920566] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.65758988] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.84059975] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.8674943] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.98354295] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.54348459] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.93540533] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.97481677] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.30672942] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.91136436] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.84936246] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.65581686] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.65917821] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.51656557] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.42193966] logical_val= 0 [ True]
# real_t_data= [0.] real_val= [0.06269619] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.52068562] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.95741749] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.22112424] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.8797948] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.96339943] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.63957033] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.88469163] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.07105248] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.81135518] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.50698944] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.7073574] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.17429571] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.65884262] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.78349779] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.30575025] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.94415371] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.88607385] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.88352346] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.77006409] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.88332027] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.92429599] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.97481013] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.85739161] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.95513324] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.59527881] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.70353039] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.52322805] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.67039307] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.24255948] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.91246018] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.14707371] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.64215252] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.04383262] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.69240655] logical_val= 1 [ True]
# real_t_data= [1.] real_val= [0.56141292] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.71175493] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.70355123] logical_val= 1 [False]
# real_t_data= [0.] real_val= [0.91420024] logical_val= 1 [False]
# real_t_data= [1.] real_val= [0.94846582] logical_val= 1 [ True]
# real_t_data= [0.] real_val= [0.23114147] logical_val= 0 [ True]
# real_t_data= [1.] real_val= [0.45208266] logical_val= 0 [False]
# real_t_data= [1.] real_val= [0.96494925] logical_val= 1 [ True]
# 정확도 :  0.7665198237885462
